# %%
import nltk
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.probability import FreqDist

text = "language modelinng is an important part of natural language processing."
tokens = word_tokenize(text.lower())

bigrams = list(ngrams(tokens, 2))

freq = FreqDist(bigrams)

print("Bigrams frequency:")
for k,v in freq.items():
    print(k, ":", v)

print("\nMost Common Bigrams:")
print(freq.most_common(5))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Bigrams frequency:
# ('language', 'modelinng') : 1
# ('modelinng', 'is') : 1
# ('is', 'an') : 1
# ('an', 'important') : 1
# ('important', 'part') : 1
# ('part', 'of') : 1
# ('of', 'natural') : 1
# ('natural', 'language') : 1
# ('language', 'processing') : 1
# ('processing', '.') : 1
#
# Most Common Bigrams:
# [(('language', 'modelinng'), 1), (('modelinng', 'is'), 1), (('is', 'an'), 1), (('an', 'important'), 1), (('important', 'part'), 1)]

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from nltk.probability import FreqDist

text = "Natural language processing enables machine to understand human language."

token = word_tokenize(text.lower())

unigrams = tokens
bigrams = list(ngrams(token, 2))
trigrams = list(ngrams(token, 3))

print("Unigrams:", unigrams)
print("Bigram:",bigrams)
print("Trigrams:", trigrams)

print("\nMost Common Unigrams:")
print(FreqDist(unigrams).most_common(5))

print("\nMost Common Bigrams:")
print(FreqDist(bigrams).most_common(5))

print("\nMost Common Trigrams:")
print(FreqDist(trigrams).most_common(5))
# Out:
# Unigrams: ['language', 'modelinng', 'is', 'an', 'important', 'part', 'of', 'natural', 'language', 'processing', '.']
# Bigram: [('natural', 'language'), ('language', 'processing'), ('processing', 'enables'), ('enables', 'machine'), ('machine', 'to'), ('to', 'understand'), ('understand', 'human'), ('human', 'language'), ('language', '.')]
# Trigrams: [('natural', 'language', 'processing'), ('language', 'processing', 'enables'), ('processing', 'enables', 'machine'), ('enables', 'machine', 'to'), ('machine', 'to', 'understand'), ('to', 'understand', 'human'), ('understand', 'human', 'language'), ('human', 'language', '.')]
#
# Most Common Unigrams:
# [('language', 2), ('modelinng', 1), ('is', 1), ('an', 1), ('important', 1)]
#
# Most Common Bigrams:
# [(('natural', 'language'), 1), (('language', 'processing'), 1), (('processing', 'enables'), 1), (('enables', 'machine'), 1), (('machine', 'to'), 1)]
#
# Most Common Trigrams:
# [(('natural', 'language', 'processing'), 1), (('language', 'processing', 'enables'), 1), (('processing', 'enables', 'machine'), 1), (('enables', 'machine', 'to'), 1), (('machine', 'to', 'understand'), 1)]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
