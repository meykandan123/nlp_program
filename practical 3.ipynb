# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\vishnu bharathi . b\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

text = "NLTK is useful for text processing"
tokens = word_tokenize(text)

fdist = FreqDist(tokens)
print(fdist)
# Out:
# <FreqDist with 6 samples and 6 outcomes>

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\vishnu bharathi .
# [nltk_data]     B\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
text="natural language processing enables machines to understand human languages."

# %%
tokens=word_tokenize(text)

# %%
freq_dist=FreqDist(tokens)

# %%
print("Word Frequencies:",freq_dist)
print("Most Common Words:",freq_dist.most_common(5))
print("Vocabulary Size:",len(freq_dist))
# Out:
# Word Frequencies: <FreqDist with 10 samples and 10 outcomes>
# Most Common Words: [('natural', 1), ('language', 1), ('processing', 1), ('enables', 1), ('machines', 1)]
# Vocabulary Size: 10
