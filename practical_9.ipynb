# %%
from textblob import TextBlob

# Sample reviews
reviews = [
    "I love this product, it is amazamazing!",
    "This is the worst purchase Iever made.",
    "The product is okay, not great."
]

#Sentiment Analysts

for review in reviews:
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    if polarity > 8:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"
    print(f"Review: {review}\nSentiment: {sentiment} \nPolarity: {polarity}\n")
# Out:
# Review: I love this product, it is amazamazing!
# Sentiment: Neutral
# Polarity: 0.625
#
# Review: This is the worst purchase Iever made.
# Sentiment: Negative
# Polarity: -1.0
#
# Review: The product is okay, not great.
# Sentiment: Neutral
# Polarity: 0.04999999999999999
